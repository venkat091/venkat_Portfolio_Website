# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Thispc\Downloads\Super_Data_Science\Courses\Python Programming Course\Advanced Visualization

# %%
movies = pd.read_csv("P4-Movie-Ratings.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.columns = ['Film', 'Genre', 'CriticsRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticsRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
len(movies)
# Out:
# 559

# %%
movies.describe()
# Out:
#        CriticsRating  AudienceRating  BudgetMillions         Year
# count     559.000000      559.000000      559.000000   559.000000
# mean       47.309481       58.744186       50.236136  2009.152057
# std        26.413091       16.826887       48.731817     1.362632
# min         0.000000        0.000000        0.000000  2007.000000
# 25%        25.000000       47.000000       20.000000  2008.000000
# 50%        46.000000       58.000000       35.000000  2009.000000
# 75%        70.000000       72.000000       65.000000  2010.000000
# max        97.000000       96.000000      300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticsRating   559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticsRating  AudienceRating  BudgetMillions
# count     559.000000      559.000000      559.000000
# mean       47.309481       58.744186       50.236136
# std        26.413091       16.826887       48.731817
# min         0.000000        0.000000        0.000000
# 25%        25.000000       47.000000       20.000000
# 50%        46.000000       58.000000       35.000000
# 75%        70.000000       72.000000       65.000000
# max        97.000000       96.000000      300.000000

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#jointplot
vis1 = sns.jointplot(data = movies, x = 'CriticsRating', y = 'AudienceRating')

# %%
vis2 = sns.jointplot(data = movies, x = 'CriticsRating', y = 'AudienceRating', kind = 'hex')

# %% [markdown]
# Histograms

# %%
m1 = plt.hist(movies.AudienceRating, bins = 10)

# %%
m2 = plt.hist(movies.CriticsRating, bins = 10)

# %% [markdown]
# Stacked Histograms

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 30)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Actions'].BudgetMillions, bins = 30)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 30)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 30)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Actions'].BudgetMillions, 
          movies[movies.Genre == 'Thriller'].BudgetMillions, 
          movies[movies.Genre == 'Drama'].BudgetMillions], bins = 15, stacked = True)
plt.show()

# %%
list1 = []
labels1 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    labels1.append(gen)
vis4 = plt.hist(list1, bins = 15, stacked = True, rwidth = 1, label =labels1)
plt.legend()
plt.show()

# %%
vis4 = plt.hist(list1, bins = 15, stacked = True, rwidth = 1, label =labels1)
plt.legend()
plt.show()

# %%
k1 = sns.kdeplot(movies.CriticsRating, movies.AudienceRating, shades = True, shade_lowest = False, cmap = "Reds")

# %% [markdown]
# subplots

# %%
f, axes = plt.subplots(1, 2, figsize = (12,6), sharex = True, sharey = True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticsRating, ax = axes[1])
k1.set(xlim = (-40,250))
# Out:
# [(-40.0, 250.0)]

# %% [markdown]
# Creaating a FacetGrid

# %%
movies.head()
# Out:
#                     Film      Genre  CriticsRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
keys = dict(s =50, linewidth = 0.5, edgecolor = 'black')
g = g.map(plt.scatter, 'CriticsRating', 'AudienceRating', **keys)

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
keys = dict(s =50, linewidth = 0.5, edgecolor = 'black')
g = g.map(plt.scatter, 'CriticsRating', 'AudienceRating', **keys)
g.set(xlim = (0, 100), ylim = (0, 100))
for ax in g.axes.flat: # creating diagonals
    ax.plot((0,100), (0, 100), c = 'gray', ls = "--")
g.add_legend()

# %% [markdown]
# Dashboard

# %%
f, axes = plt.subplots(3, 2, figsize = (15,12))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticsRating, ax = axes[0,1])
k3 = sns.violinplot(data = movies, x = 'Year', y = 'BudgetMillions', ax =axes[1,0])
k4 = sns.kdeplot(movies.CriticsRating, movies.AudienceRating, shades = True, shade_lowest = False, cmap = "Reds", ax =axes[1,1])
axes[2,0].hist(movies.AudienceRating, bins = 10)
axes[2,1].hist(movies.CriticsRating, bins = 10)
plt.show()

# %%
sns.set_style('dark', {'axes.facecolor':'black'})
f, axes = plt.subplots(3, 2, figsize = (15,12))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0,0], shade = True, 
                 shade_lowest = True, cmap = 'inferno')
k1b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0,0], cmap = 'cool', )
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticsRating, ax = axes[0,1], shade = True, 
                 shade_lowest = True, cmap = 'inferno')
k2b = sns.kdeplot(movies.BudgetMillions, movies.CriticsRating, ax = axes[0,1], cmap = 'cool')
k3 = sns.violinplot(data = movies, x = 'Year', y = 'BudgetMillions', ax =axes[1,0], palette = 'YlOrRd')
k4 = sns.kdeplot(movies.CriticsRating, movies.AudienceRating, ax =axes[1,1], shade = True, 
                 shade_lowest = False, cmap = "Blues_r")
k4b = sns.kdeplot(movies.CriticsRating, movies.AudienceRating, ax =axes[1,1], cmap = "gist_gray_r")
axes[2,0].hist(movies.AudienceRating, bins = 10, color = 'Brown')
axes[2,1].hist(movies.CriticsRating, bins = 10, color = 'Brown')
plt.show()

# %%
list1 = []
labels1 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    labels1.append(gen)

sns.set_style("whitegrid")
fig, ax = plt.subplots()
vis4 = plt.hist(list1, bins = 15, stacked = True, rwidth = 1, label =labels1)
fig.set_size_inches(10,8)
plt.title("Movies Budget Distribution", fontsize = 25, color ="Green")
plt.xlabel("BudgetMillions", color = "Blue", fontsize = 18)
plt.ylabel("No. of Movies", color = "Red", fontsize = 18)
plt.legend(frameon = True,fancybox = True, shadow = True, framealpha = 1, prop = {"size":15})
plt.show()
